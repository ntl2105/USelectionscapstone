# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("US_County_Level_Presidential_Results_12-16.csv")
county_facts = pd.read_csv("county_facts.csv")
df08 = pd.read_csv("US_County_Level_Presidential_Results_08-16.csv")

# %%
df.head(20)
# Out:
#     Unnamed: 0  combined_fips  votes_dem_2016  votes_gop_2016  \
# 0            0           2013         93003.0        130413.0
# 1            1           2016         93003.0        130413.0
# 2            2           2020         93003.0        130413.0
# 3            3           2050         93003.0        130413.0
# 4            4           2060         93003.0        130413.0
# 5            5           2068         93003.0        130413.0
# 6            6           2070         93003.0        130413.0
# 7            7           2090         93003.0        130413.0
# 8            8           2100         93003.0        130413.0
# 9            9           2105         93003.0        130413.0
# 10          10           2110         93003.0        130413.0
# 11          11           2122         93003.0        130413.0
# 12          12           2130         93003.0        130413.0
# 13          13           2150         93003.0        130413.0
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# combined_fips           0
# votes_dem_2016          0
# votes_gop_2016          0
# total_votes_2016        0
# per_dem_2016            0
# per_gop_2016            0
# diff_2016               0
# per_point_diff_2016     0
# state_abbr              0
# county_name             0
# FIPS                    0
# total_votes_2012       29
# votes_dem_2012         29
# votes_gop_2012         29
# county_fips            29
# state_fips             29
# per_dem_2012           29
# per_gop_2012           29
# diff_2012              29
# per_point_diff_2012    29
# dtype: int64

# %%
df.shape
# Out:
# (3141, 21)

# %%
df.loc[df['state_abbr'] == "CA"].shape
# Out:
# (58, 21)

# %%
county_facts.loc[county_facts['fips'] == 1003]
# Out:
#    fips       area_name state_abbreviation  PST045214  PST040210  PST120214  \
# 3  1003  Baldwin County                 AL     200111     182265        9.8
#
#    POP010210  AGE135214  AGE295214  AGE775214  SEX255214  RHI125214  \
# 3     182265        5.6       22.2       18.7       51.2       87.1
#
#    RHI225214  RHI325214  RHI425214  RHI525214  RHI625214  RHI725214  \
# 3        9.6        0.7        0.9        0.1        1.6        4.6
#
#    RHI825214  POP715213  POP645213  POP815213  EDU635213  EDU685213  \
# 3       83.0       82.1        3.6        5.5       89.1       27.7
#
#    VET605213  LFE305213  HSG010214  HSG445213  HSG096213  HSG495213  \
# 3      19346       25.9     107374       72.6       24.4     168600
#
#    HSD410213  HSD310213  INC910213  INC110213  PVY020213  BZA010213  \
# 3      73283       2.52      26766      50221       13.9       4871
#
#    BZA110213  BZA115213  NES010213  SBO001207  SBO315207  SBO115207  \
# ...

# %%
df.loc[df['FIPS'] == 1003]
# Out:
#     Unnamed: 0  combined_fips  votes_dem_2016  votes_gop_2016  \
# 30          30           1003         18409.0         72780.0
#
#     total_votes_2016  per_dem_2016  per_gop_2016  diff_2016  \
# 30           94090.0      0.195653      0.773515      54371
#
#     per_point_diff_2016 state_abbr     county_name  FIPS  total_votes_2012  \
# 30            -0.577862         AL  Baldwin County  1003           84988.0
#
#     votes_dem_2012  votes_gop_2012  county_fips  state_fips  per_dem_2012  \
# 30         18329.0         65772.0          3.0         1.0      0.215666
#
#     per_gop_2012  diff_2012  per_point_diff_2012
# 30      0.773897    47443.0            -0.558232

# %%
gop_wins_2016 = df.loc[df['per_gop_2016'] > df['per_dem_2016']]

# %%
gop_wins_2016.shape #(2654, 21)
# Out:
# (2654, 21)

# %%
gop_wins_2016.loc[gop_wins_2016["per_gop_2012"] < gop_wins_2016["per_dem_2012"]]['state_abbr'].value_counts()
#219 counties voted R in 2016 while they voted D in 2012.
# Out:
# 219

# %%
dem_wins_2016 = df.loc[df['per_gop_2016'] < df['per_dem_2016']]

# %%
dem_wins_2016.loc[dem_wins_2016["per_gop_2012"] > dem_wins_2016["per_dem_2012"]]['state_abbr'].value_counts()
#20 counties voted D in 2016 while they voted R in 2012.
# Out:
# 20

# %%
county_facts.loc[county_facts['area_name'] == "Big Horn County"]
# Out:
#        fips        area_name state_abbreviation  PST045214  PST040210  \
# 1627  30003  Big Horn County                 MT      13282      12865
# 3173  56003  Big Horn County                 WY      11930      11668
#
#       PST120214  POP010210  AGE135214  AGE295214  AGE775214  SEX255214  \
# 1627        3.2      12865       10.3       33.5       11.4       50.8
# 3173        2.2      11668        6.5       25.3       19.2       49.7
#
#       RHI125214  RHI225214  RHI325214  RHI425214  RHI525214  RHI625214  \
# 1627       31.9        0.4       64.4        0.5        0.0        2.8
# 3173       95.9        0.9        1.3        0.4        0.0        1.4
#
#       RHI725214  RHI825214  POP715213  POP645213  POP815213  EDU635213  \
# 1627        5.6       29.6       91.4        1.2       29.9       84.5
# 3173        9.1       87.8       87.7        2.6        7.1       89.1
#
#       EDU685213  VET605213  LFE305213  HSG010214  HSG445213  HSG096213  \
# ...

# %%
sum(df['combined_fips'] == df["FIPS"])
# Out:
# 3141

# %%
df.shape
# Out:
# (3141, 21)

# %%
df_merged = pd.merge(df, county_facts, how='inner', left_on="FIPS", right_on="fips",
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False)

# %%
df_merged.head()
# Out:
#    Unnamed: 0  combined_fips  votes_dem_2016  votes_gop_2016  \
# 0          29           1001          5908.0         18110.0
# 1          30           1003         18409.0         72780.0
# 2          31           1005          4848.0          5431.0
# 3          32           1007          1874.0          6733.0
# 4          33           1009          2150.0         22808.0
#
#    total_votes_2016  per_dem_2016  per_gop_2016  diff_2016  \
# 0           24661.0      0.239569      0.734358      12202
# 1           94090.0      0.195653      0.773515      54371
# 2           10390.0      0.466603      0.522714        583
# 3            8748.0      0.214220      0.769662       4859
# 4           25384.0      0.084699      0.898519      20658
#
#    per_point_diff_2016 state_abbr     county_name  FIPS  total_votes_2012  \
# 0            -0.494789         AL  Autauga County  1001           23909.0
# 1            -0.577862         AL  Baldwin County  1003           84988.0
# ...

# %%
df08.head()
# Out:
#    fips_code              county  total_2008  dem_2008  gop_2008  oth_2008  \
# 0      26041        Delta County       19064      9974      8763       327
# 1      48295     Lipscomb County        1256       155      1093         8
# 2       1127       Walker County       28652      7420     20722       510
# 3      48389       Reeves County        3077      1606      1445        26
# 4      56017  Hot Springs County        2546       619      1834        93
#
#    total_2012  dem_2012  gop_2012  oth_2012  total_2016  dem_2016  gop_2016  \
# 0       18043      8330      9533       180       18467      6431     11112
# 1        1168       119      1044         5        1322       135      1159
# 2       28497      6551     21633       313       29243      4486     24208
# 3        2867      1649      1185        33        3184      1659      1417
# 4        2495       523      1894        78        2535       400      1939
#
#    oth_2016
# 0       924
# 1        28
# 2       549
# ...

# %%
df_merged["RHI425214"]
# Out:
# 0       1.1
# 1       0.9
# 2       0.5
# 3       0.2
# 4       0.3
# 5       0.3
# 6       0.9
# 7       0.9
# 8       0.8
# 9       0.3
# 10      0.4
# 11      0.3
# 12      0.5
# 13      0.3
# 14      0.2
# 15      1.6
# 16      0.5
# 17      0.1
# 18      0.2
# 19      0.5
# 20      1.8
# 21      0.5
# 22      1.3
# 23      0.5
# 24      0.4
# 25      0.7
# 26      0.3
# 27      0.8
# 28      0.3
# 29      0.4
#        ...
# 3111    0.5
# 3112    1.2
# 3113    3.3
# 3114    0.5
# 3115    0.5
# 3116    2.7
# 3117    2.0
# 3118    3.1
# 3119    0.4
# 3120    0.6
# 3121    1.0
# 3122    0.6
# 3123    0.4
# 3124    0.6
# 3125    0.7
# 3126    0.5
# 3127    1.0
# 3128    1.3
# 3129    0.4
# 3130    0.9
# 3131    0.4
# 3132    0.8
# 3133    0.5
# 3134    0.9
# 3135    1.3
# 3136    0.9
# 3137    1.3
# 3138    0.5
# 3139    0.7
# 3140    0.4
# Name: RHI425214, Length: 3141, dtype: float64

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.scatter(x = df_merged["POP645213"], y = df_merged['per_gop_2016'])
plt.xlabel('Foreign Born Pop 2009-2013')
plt.ylabel('GOP Percentage Votes 2016')
plt.show()

# %%
plt.hist(df_merged['per_gop_2016'], bins=50, color="#666699")
plt.show()

# %%
plt.hist((1 - df_merged['per_dem_2016']), bins = 50, color= "#389247")
plt.show()

# %%
plt.hist(df_merged['per_dem_2016'], bins=50, color="#264670")
plt.show()

# %%
#df_merged["INC110213"] #median household income 2009-2013
sns.lmplot(x = "INC110213", y = "per_gop_2016", data = df_merged)

# %%
# POP010210
logx = np.log(df_merged["POP010210"])
plt.scatter(x = logx, y = df_merged['per_gop_2016'])
plt.xlabel("Population, 2010")
plt.ylabel('GOP Percentage Votes 2016')
plt.show()

# %%
#Population per county 
sns.lmplot(x = "POP010210", y = "per_gop_2016", data = df_merged, logx = True)
# Out:
# //anaconda/lib/python3.5/site-packages/seaborn/linearmodels.py:267: RuntimeWarning: invalid value encountered in log
#   grid = np.c_[np.ones(len(grid)), np.log(grid)]

# %%
plt.hist(np.log(df_merged["POP010210"]), bins=50, color="#264670")
plt.show()

# %%
logx = np.log(df_merged["SBO001207"]) 
plt.scatter(x = logx, y = df_merged['per_gop_2016'])
plt.xlabel("Total number of firms, 2007")
plt.ylabel('GOP Percentage Votes 2016')
plt.show()
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
def makeCategory(df):
    for x in range(len(df) -1):
        if df["per_gop_2016"][x] > df["per_dem_2016"][x]:
            result = 1
        else:
            result = 0
    return result

# %%
df_merged["per_gop_2016"][0] > df_merged["per_dem_2016"][0]
# Out:
# True

# %%
# result_list = []
# for x in range(len(df_merged)):
#         if df_merged["per_gop_2016"][x] > df_merged["per_dem_2016"][x]:
#             result = 1
#         else:
#             result = 0
#         result_list.append(result)

result_list_2 = []
for x in range(len(df_merged)):
        if df_merged["per_gop_2012"][x] > df_merged["per_dem_2012"][x]:
            result = 1
        else:
            result = 0
        result_list_2.append(result)

# %%
#turning list object into data frame
result_list = pd.DataFrame(result_list, columns = ["Outcome_2016"])
#addig election outcome 2016 column to main dataframe df_merged
df_merged = pd.concat([df_merged,result_list], axis=1)

#turning list object into data frame
result_list_2 = pd.DataFrame(result_list_2, columns = ["Outcome_2012"])
#addig election outcome 2012 column to main dataframe df_merged
df_merged = pd.concat([df_merged,result_list_2], axis=1)

# %%
df_merged.to_csv(path_or_buf  = "df_merged.csv")
